# %%
run_query("03_average_ticket.sql")
# Out:
#    TicketMedio
# 0    3915.9951

# %%
run_query("02_orders.sql")
# Out:
#    TotalPedidos
# 0         31465

# %%
from query_executor import run_query

df = run_query("01_revenue.sql")

df
# Out:
#    ReceitaTotal
# 0  1.232168e+08
